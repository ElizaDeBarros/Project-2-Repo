# %%
import zipfile
import pandas as pd
import os

# Name of zip file that will be downloaded.
zip_name = "global-shark-attacks.zip"
# Check if local machine has this zip file already in location of notebook.
# If it does not, it downloads it.
if not os.path.exists(zip_name):
    # !kaggle datasets download -d teajay/global-shark-attacks
    
# Name of folder that csv files will export to.
folder_name = "Resources"
# Check if local machine has this folder created already in location of notebook.
# If it does not, it creates it.
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    
path_to_zip_file = 'global-shark-attacks.zip'
directory_to_extract_to = folder_name

with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %%
import zipfile
import pandas as pd
import os

csv_file = "attacks.csv"
#Reads in CSV file into pandas dataframe.
df = pd.read_csv(f"Resources/{csv_file}", sep=',', encoding='latin-1')
#prints the total rows of the dataframe.
print(f"This table started with {len(df.index)} rows.")

#### 'Case Number', 'Year', 'Country', 'Fatal (Y/N)', 'Time', need to not be null
df = df[df['Case Number'].notna()]
df = df[df['Year'].notna()]
df = df[df['Country'].notna()]
df = df[df['Fatal (Y/N)'].notna()]
df = df[df['Time'].notna()]


df = df.loc[df['Time'] != 'X']
df = df.loc[(df['Fatal (Y/N)'] == 'Y') | (df['Fatal (Y/N)'] == 'N')]
df1 = df.loc[(df['Year'] != 0.0) & (df['Year'] >= 1980)]

#prints the row count after null values have been dropped.
print(f"After dropping null values there are {len(df1.index)} rows.")

df1
# Out:
# This table started with 25723 rows.
# After dropping null values there are 1917 rows.
#        Case Number         Date    Year        Type       Country  \
# 0       2018.06.25  25-Jun-2018  2018.0     Boating           USA
# 1       2018.06.18  18-Jun-2018  2018.0  Unprovoked           USA
# 2       2018.06.09  09-Jun-2018  2018.0     Invalid           USA
# 6     2018.06.03.a  03-Jun-2018  2018.0  Unprovoked        BRAZIL
# 8     2018.05.26.b  26-May-2018  2018.0  Unprovoked           USA
# ...            ...          ...     ...         ...           ...
# 3073    1980.01.31  31-Jan-1980  1980.0  Unprovoked  SOUTH AFRICA
# 3075    1980.01.15  15-Jan-1980  1980.0    Provoked  SOUTH AFRICA
# 3077    1980.01.10  10-Jan-1980  1980.0  Unprovoked  SOUTH AFRICA
# 3078    1980.01.05  05-Jan-1980  1980.0  Unprovoked         CHILE
# 3082  1980.00.00.a       1980s   1980.0  Unprovoked         TONGA
#
#                        Area                        Location       Activity  \
# ...

# %%
for column in df.columns:
    print(column)
# Out:
# Case Number
# Date
# Year
# Type
# Country
# Area
# Location
# Activity
# Name
# Sex
# Age
# Injury
# Fatal (Y/N)
# Time
# Species
# Investigator or Source
# pdf
# href formula
# href
# Case Number.1
# Case Number.2
# original order
# Unnamed: 22
# Unnamed: 23

# %%
df1 = df1[["Case Number", "Date", "Year", "Type", "Country", "Area",
          "Location", "Activity", "Name", "Sex ", 
          "Age", "Injury",
          "Fatal (Y/N)", "Time", "Species ", 
          "Investigator or Source",
          "pdf", "href"]]

df1 = df1.rename(columns={"Sex ": "Sex", "Species ": "Species"})


df2 = df1.set_index(["Case Number"])
df2
# Out:
#                      Date    Year        Type       Country  \
# Case Number
# 2018.06.25    25-Jun-2018  2018.0     Boating           USA
# 2018.06.18    18-Jun-2018  2018.0  Unprovoked           USA
# 2018.06.09    09-Jun-2018  2018.0     Invalid           USA
# 2018.06.03.a  03-Jun-2018  2018.0  Unprovoked        BRAZIL
# 2018.05.26.b  26-May-2018  2018.0  Unprovoked           USA
# ...                   ...     ...         ...           ...
# 1980.01.31    31-Jan-1980  1980.0  Unprovoked  SOUTH AFRICA
# 1980.01.15    15-Jan-1980  1980.0    Provoked  SOUTH AFRICA
# 1980.01.10    10-Jan-1980  1980.0  Unprovoked  SOUTH AFRICA
# 1980.01.05    05-Jan-1980  1980.0  Unprovoked         CHILE
# 1980.00.00.a       1980s   1980.0  Unprovoked         TONGA
#
#                                Area                        Location  \
# Case Number
# 2018.06.25               California     Oceanside, San Diego County
# 2018.06.18                  Georgia  St. Simon Island, Glynn County
# ...

# %%
country_df = df2['Country'].unique()
country_df
# Out:
# array(['USA', 'BRAZIL', 'AUSTRALIA', 'ENGLAND', 'SOUTH AFRICA',
#        'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA', 'CUBA',
#        'MAURITIUS', 'NEW ZEALAND', 'SAMOA', 'JAPAN',
#        'ST HELENA, British overseas territory', 'SPAIN', 'REUNION',
#        'UNITED ARAB EMIRATES', 'MEXICO', 'INDONESIA', 'COLUMBIA', 'EGYPT',
#        'FRENCH POLYNESIA', 'Fiji', 'DOMINICAN REPUBLIC', 'ECUADOR',
#        'MOZAMBIQUE', 'THAILAND', 'PUERTO RICO', 'FRANCE',
#        'PAPUA NEW GUINEA', 'ISRAEL', 'PALESTINIAN TERRITORIES', 'JAMAICA',
#        'RUSSIA', 'SEYCHELLES', 'TURKS & CAICOS', 'FIJI', 'TONGA',
#        'SOUTH KOREA', 'VIETNAM', 'MADAGASCAR',
#        'UNITED ARAB EMIRATES (UAE)', 'PANAMA', 'SCOTLAND',
#        'UNITED KINGDOM', 'TAIWAN', 'GUAM', 'PHILIPPINES', 'CROATIA',
#        'SOLOMON ISLANDS', 'YEMEN', 'ATLANTIC OCEAN', 'ST. MAARTIN',
#        'GRAND CAYMAN', 'VANUATU', 'MEXICO ', 'VENEZUELA', 'MICRONESIA',
# ...

# %%
country_df = df2['Country'].value_counts()
country_df
# Out:
# USA               1079
# AUSTRALIA          331
# SOUTH AFRICA       183
# REUNION             42
# BRAZIL              39
#                   ...
# ISRAEL               1
# GRAND CAYMAN         1
# SCOTLAND             1
# ATLANTIC OCEAN       1
# MICRONESIA           1
# Name: Country, Length: 65, dtype: int64

# %%
country_df = df2['Activity'].value_counts()
country_df
# Out:
# Surfing                                           678
# Swimming                                          247
# Spearfishing                                       98
# Wading                                             78
# Fishing                                            69
#                                                  ...
# Fishing for yellowtail, Seriola quinqueradiata      1
# Floating                                            1
# Skindiving                                          1
# Paddle-surfing                                      1
# Spearfishing (Free diving)                          1
# Name: Activity, Length: 304, dtype: int64

# %%
country_df = df2['Fatal (Y/N)'].value_counts()
country_df
# Out:
# N    1725
# Y     192
# Name: Fatal (Y/N), dtype: int64

# %%
USA_df = df2.loc[df2["Country"] == "USA"]
USA_df
#37.0902° N, 95.7129° W
#37.0902, -95.7129
# Out:
#                      Date    Year        Type Country        Area  \
# Case Number
# 2018.06.25    25-Jun-2018  2018.0     Boating     USA  California
# 2018.06.18    18-Jun-2018  2018.0  Unprovoked     USA     Georgia
# 2018.06.09    09-Jun-2018  2018.0     Invalid     USA      Hawaii
# 2018.05.26.b  26-May-2018  2018.0  Unprovoked     USA     Florida
# 2018.05.26.a  26-May-2018  2018.0  Unprovoked     USA     Florida
# ...                   ...     ...         ...     ...         ...
# 1981.02.02    02-Feb-1981  1981.0  Unprovoked     USA     Florida
# 1980.10.27    27-Oct-1980  1980.0  Unprovoked     USA      Oregon
# 1980.10.17    17-Oct-1980  1980.0  Unprovoked     USA  California
# 1980.07.27    27-Jul-1980  1980.0  Unprovoked     USA  New Jersey
# 1980.07.23    23-Jul-1980  1980.0  Unprovoked     USA    Delaware
#
#                                       Location      Activity  \
# Case Number
# 2018.06.25         Oceanside, San Diego County      Paddling
# ...

# %%
Australia_df = df2.loc[df2["Country"] == "AUSTRALIA"]
Australia_df
#25.2744° S, 133.7751° E
# Out:
#                      Date    Year          Type    Country               Area  \
# Case Number
# 2018.05.24    24-May-2018  2018.0      Provoked  AUSTRALIA         Queensland
# 2018.01.12        12-Jan-2018  2018.0  Unprovoked  BRAZIL
# 2017.02.06.b      06-Feb-2017  2017.0    Provoked  BRAZIL
# 2017.01.24        24-Jan-2017  2017.0  Unprovoked  BRAZIL
# 2013.07.22        22-Jul-2013  2013.0  Unprovoked  BRAZIL
# 2012.08.26        26-Aug-2012  2012.0  Unprovoked  BRAZIL
# 2011.06.29        29-Jun-2011  2011.0  Unprovoked  BRAZIL
# 2009.09.07        07-Sep-2009  2009.0  Unprovoked  BRAZIL
# 2008.06.24        24-Jun-2008  2008.0  Unprovoked  BRAZIL
# 2008.06.01.a      01-Jun-2008  2008.0  Unprovoked  BRAZIL
# 2006.09.03.b      03-Sep-2006  2006.0  Unprovoked  BRAZIL
# 2006.06.18        18-Jun-2006  2006.0  Unprovoked  BRAZIL
# 2006.05.21        21-May-2006  2006.0  Unprovoked  BRAZIL
# 2006.04.09.a      09-Apr-2006  2006.0  Unprovoked  BRAZIL
# 2004.08.21        21-Aug-2004  2004.0  Unprovoked  BRAZIL
# ...

# %%
England_df = df2.loc[df2["Country"] == "ENGLAND"]
England_df
#51.5074° N, 0.1278° W
# Out:
#                               Date    Year      Type  Country      Area  \
# Case Number
# 2018.05.13.a           13-May-2018  2018.0   Invalid  ENGLAND  Cornwall
# 2007.05.17.R  Reported 17-May-2007  2007.0  Provoked  ENGLAND      Kent
#
#                     Location Activity          Name Sex Age  \
# Case Number
# 2018.05.13.a  Off Land's End  Fishing  Max Berryman   M  21
# 2007.05.17.R      Folkestone  Fishing   Phil Tanner   M  38
#
#                                                          Injury Fatal (Y/N)  \
# Case Number
# 2018.05.13.a  Injured by teeth of a dead porbeagle shark he ...           N
# 2007.05.17.R  Bitten on the nose by a hooked shark PROVOKED ...           N
#
#                    Time                                            Species  \
# Case Number
# 2018.05.13.a      08h15                                   Invalid incident
# 2007.05.17.R  Afternoon  Lesser spotted dogfish, Scyliorhinus canicula,...
#
# ...

# %%
Costa_Rica_df = df2.loc[df2["Country"] == "COSTA RICA"]
Costa_Rica_df
#9.7489° N, 83.7534° W
# Out:
#                      Date    Year        Type     Country          Area  \
# Case Number
# 2018.04.28.b  28-Apr-2018  2018.0  Unprovoked  COSTA RICA  Cocos Island
# 2011.06.19.a  19-Jun-2011  2011.0  Unprovoked  COSTA RICA    Guanacaste
#
#                   Location      Activity          Name Sex Age  \
# Case Number
# 2018.04.28.b     Manuelita  Scuba diving          male   M  30
# 2011.06.19.a  Playa Grande       Surfing  Kevin Moraga   M  15
#
#                                        Injury Fatal (Y/N)   Time      Species  \
# Case Number
# 2018.04.28.b  No injury, shark bit scuba gear           N  10h40  Tiger shark
# 2011.06.19.a                            FATAL           Y  12h15          NaN
#
#                           Investigator or Source                         pdf  \
# Case Number
# 2018.04.28.b          Costa Rica Star. 4/28/2018  2018.04.28.b-CostaRica.pdf
# 2011.06.19.a  D. Martinez, Tico Times, 6/21/2011     2011.06.19.a-Moraga.pdf
#
# ...

# %%
Maldives_df = df2.loc[df2["Country"] == "MALDIVES"]
Maldives_df
#3.2028° N, 73.2207° E
# 2008.05.07.b   07-May-2008  2008.0  Unprovoked  NEW CALEDONIA
# ...

# %%
Cuba_df = df2.loc[df2["Country"] == "CUBA"]
Cuba_df
#21.5218° N, 77.7812° W
# Out:
#                     Date    Year        Type Country                 Area  \
# Case Number
# 2017.11.04   04-Nov-2017  2017.0  Unprovoked    CUBA     Holquin Province
# 2009.01.25   25-Jan-2009  2009.0  Unprovoked    CUBA  Guantanamo Province
# 2004.10.31   31-Oct-2004  2004.0  Unprovoked    CUBA    Camaguey Province
#
#                        Location       Activity                     Name Sex  \
# Case Number
# 2017.11.04   Guardalavaca Beach  Night bathing  Jesús Cabrera González    M
# 2009.01.25       Guantanamo Bay   Spearfishing               John Emory   M
# 2004.10.31          Santa Lucia         Diving                     male   M
#
#             Age                                Injury Fatal (Y/N)   Time  \
# Case Number
# 2017.11.04   22                                 FATAL           Y  23h30
# 2009.01.25   15  Severe lacerations to lower left leg           N  10h30
# 2004.10.31   40                   Left forearm bitten           N  14h00
#
# ...

# %%
Mauritius_df = df2.loc[df2["Country"] == "MAURITIUS"]
Mauritius_df
#20.3484° S, 57.5522° E
# Out:
#                      Date    Year        Type    Country            Area  \
# Case Number
# 2017.10.23.c  23-Oct-2017  2017.0  Unprovoked  MAURITIUS  Pamplemousses
# 1999.04.22    22-Apr-1999  1999.0  Unprovoked  MAURITIUS      Grand Baie
#
#                            Location  Activity           Name Sex  Age  \
# Case Number
# 2017.10.23.c              Le Goulet  Swimming           male   M  NaN
# 1999.04.22    Pointe aux Canonniers  Swimming  Sylvia Lanner   F   41
#
#                             Injury Fatal (Y/N)       Time  \
# Case Number
# 2017.10.23.c  Minor injury to foot           N  Afternoon
# 1999.04.22            Thigh bitten           N      06h00
#
#                               Species Investigator or Source  \
# Case Number
# 2017.10.23.c                      NaN       J. LeBlanc, GSAF
# 1999.04.22    Grey reef shark, 1.5 m                     NaN
#
#                                      pdf  \
# Case Number
# 2017.10.23.c  2017.10.23.c-Mauritius.pdf
# ...

# %%
New_Zealand_df = df2.loc[df2["Country"] == "NEW ZEALAND"]
New_Zealand_df
#40.9006° S, 174.8860° E
# Out:
#                      Date    Year        Type      Country  \
# Case Number
# 2017.10.21    21-Oct-2017  2017.0  Unprovoked  NEW ZEALAND
# 2017.04.27    27-Apr-2017  2017.0  Unprovoked  NEW ZEALAND
# 2016.05.02    02-May-2016  2016.0    Provoked  NEW ZEALAND
# 2014.02.07    07-Feb-2014  2014.0  Unprovoked  NEW ZEALAND
# 2013.02.27    27-Feb-2013  2013.0  Unprovoked  NEW ZEALAND
# 2012.03.06.b  06-Mar-2012  2012.0  Unprovoked  NEW ZEALAND
# 2011.04.16    16-Apr-2011  2011.0  Unprovoked  NEW ZEALAND
# 2010.02.19    190Feb-2010  2010.0  Unprovoked  NEW ZEALAND
# 2010.02.01    01-Feb-2010  2010.0    Provoked  NEW ZEALAND
# 2009.01.24.c  24-Jan-2009  2009.0        Boat  NEW ZEALAND
# 2009.01.06    06-Jan-2009  2009.0  Unprovoked  NEW ZEALAND
Indonesia_df = df2.loc[df2["Country"] == "INDONESIA"]
Indonesia_df
#0.7893° S, 113.9213° E
# Out:
#                     Date    Year        Type    Country  Area      Location  \
# Case Number
# 2017.01.09   09-Jan-2017  2017.0  Unprovoked  INDONESIA  Bali  Balian Beach
# 2016.04.25   25-Apr-2016  2016.0  Unprovoked  INDONESIA  Bali        Balian
# 2011.11.29   29-Nov-2011  2011.0  Unprovoked  INDONESIA  Bali       Tabanan
# 2011.04.12   13-Apr-2011  2011.0  Unprovoked  INDONESIA  Bali        Balian
#
#             Activity          Name Sex  Age                           Injury  \
# Case Number
# 2017.01.09   Surfing  Daniel Moore   M   48  Injury to right wrist & forearm
# 2016.04.25   Surfing  Ryan Boarman   M   24                     Elbow bitten
# 2011.11.29   Surfing  Marc Andrews   M   18        Lacerations to right hand
# 2011.04.12   Surfing    Joe Ferrar   M  NaN           Lacerations to forearm
#
#             Fatal (Y/N)     Time             Species  \
# Case Number
# 2017.01.09            N    07h30     Bull shark, 1 m
# ...

# %%
Columbia_df = df2.loc[df2["Country"] == "COLUMBIA"]
Columbia_df
#34.0007° N, 81.0348° W

# %%
Egypt_df = df2.loc[df2["Country"] == "EGYPT"]
Egypt_df
#26.8206° N, 30.8025° E
# Out:
#                      Date    Year          Type Country  \
# Case Number
# 2016.06.04    04-Jun-2016  2016.0    Unprovoked   EGYPT
# 2010.12.05    05-Dec-2010  2010.0    Unprovoked   EGYPT
# 2010.12.01.b  01-Dec-2010  2010.0    Unprovoked   EGYPT
# 2010.12.01.a  01-Dec-2010  2010.0    Unprovoked   EGYPT
# 2010.11.30.b  30-Nov-2010  2010.0    Unprovoked   EGYPT
# 2010.11.30.a  30-Nov-2010  2010.0    Unprovoked   EGYPT
# 2010.10.20    20-Oct-2010  2010.0    Unprovoked   EGYPT
# 2010.04.04    04-Apr-2010  2010.0    Unprovoked   EGYPT
# 2009.06.01    01-Jun-2009  2009.0    Unprovoked   EGYPT
# 2008.11.28    28-Nov-2008  2008.0    Unprovoked   EGYPT
# 2007.09.27.a  27-Sep-2007  2007.0    Unprovoked   EGYPT
# 2004.01.03.a  03-Jan-2004  2004.0  Sea Disaster   EGYPT
#
#                                Area                        Location  \
# Case Number
# 2016.06.04                     Suez                      Ain Sokhna
# 2010.12.05    South Sinai Peninsula  Middle Garden, Sharm el-Shiekh
# ...

# %%
French_Polynesia_df = df2.loc[df2["Country"] == "FRENCH POLYNESIA"]
French_Polynesia_df
#17.6797° S, 149.4068° W
# Out:
#                      Date    Year        Type           Country  \
# Case Number
# 2016.04.18.a  18-Apr-2016  2016.0    Provoked  FRENCH POLYNESIA
# 2015.05.25    25-May-2015  2015.0  Unprovoked  FRENCH POLYNESIA
# 2015.03.16    16-Mar-2015  2015.0  Unprovoked  FRENCH POLYNESIA
# 2014.02.20    20-Feb-2014  2014.0  Unprovoked  FRENCH POLYNESIA
# 2013.04.10    10-Apr-2013  2013.0  Unprovoked  FRENCH POLYNESIA
# 2013.02.09    09-Feb-2013  2013.0  Unprovoked  FRENCH POLYNESIA
# 2011.08.16.c  16-Aug-2011  2011.0  Unprovoked  FRENCH POLYNESIA
#
#                          Area  \
# Case Number
# 2016.04.18.a         Tuamotos
# 2015.05.25           Rangiroa
# 2015.03.16          Bora Bora
# 2014.02.20    Society Islands
# 2013.04.10           Tuamotus
# 2013.02.09    Society Islands
# 2011.08.16.c  Society Islands
#
#                                                        Location  \
# Case Number
# 2016.04.18.a                                       Makemo Atoll
# ...

# %%
Fiji_df = df2.loc[df2["Country"] == "Fiji"]
Fiji_df
#17.7134° S, 178.0650° E
# Out:
#                     Date    Year        Type Country        Area Location  \
# Case Number
# 2016.03.10   10-Mar-2016  2016.0  Unprovoked    Fiji  Vanua Levu      NaN
#
#                             Activity         Name Sex Age Injury Fatal (Y/N)  \
# Case Number
# 2016.03.10   Diving for beche-de-mer  Maika Tabua   M  45  FATAL           Y
#
#                   Time Species Investigator or Source                   pdf  \
# Case Number
# 2016.03.10   Afternoon     NaN    Fiji Sun, 3/12/2016  2016.03.10-Tabua.pdf
#
#                                                           href
# Case Number
# 2016.03.10   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
DR_df = df2.loc[df2["Country"] == "DOMINICAN REPUBLIC"]
DR_df
#18.7357° N, 70.1627° W
# Out:
#                     Date    Year        Type             Country  \
# Case Number
# 2016.02.12   12-Feb-2016  2016.0  Unprovoked  DOMINICAN REPUBLIC
# 2010.11.15   15-Nov-2010  2010.0  Unprovoked  DOMINICAN REPUBLIC
#
#                             Area                  Location Activity  \
# Case Number
# 2016.02.12   Altagracia Province  Bavaro Beach, Punta Cana   Wading
# 2010.11.15                   NaN                Boca Chica   Diving
#
#                              Name Sex  Age                        Injury  \
# Case Number
# 2016.02.12          Patricia Howe   F  NaN  Avulsion injury to lower leg
# 2010.11.15   Pinales Pedro Zapata   M   21                         FATAL
#
#             Fatal (Y/N)     Time Species       Investigator or Source  \
# Case Number
# 2016.02.12            N    15h00     NaN                    S. Harris
# 2010.11.15            Y  Morning     NaN  Dominican Today, 11/15/2010
#
#                                pdf  \
# Case Number
# ...

# %%
Ecuador_df = df2.loc[df2["Country"] == "ECUADOR"]
Ecuador_df
#1.8312° S, 78.1834° W
# Out:
#                     Date    Year        Type  Country               Area  \
# Case Number
# 2015.11.20   20-Nov-2015  2015.0  Unprovoked  ECUADOR  Galapagos Islands
# 2013.05.14   14-May-2014  2013.0  Unprovoked  ECUADOR  Santa Cruz Island
# 2011.12.25   25-Dec-2011  2011.0  Unprovoked  ECUADOR        Santa Elena
#
#                                         Location    Activity  \
# Case Number
# 2015.11.20   Punta Vicente Roca, Isabella Island  Snorkeling
# 2013.05.14               Playa Brava, Turtle Bay     Surfing
# 2011.12.25                        Barandúa Beach     Surfing
#
#                                    Name Sex Age  \
# Case Number
# 2015.11.20                Graham Hurley   M  55
# 2013.05.14               Intriago Diego   M  29
# 2011.12.25   Félix Júnior Lainez Trejos   M  23
#
#                                          Injury Fatal (Y/N)   Time  \
# Case Number
# 2015.11.20             Lacerations to left calf           N  10h15
# ...

# %%
Mozambique_df = df2.loc[df2["Country"] == "MOZAMBIQUE"]
Mozambique_df
#18.6657° S, 35.5296° E
# Out:
#                      Date    Year        Type     Country                Area  \
# Case Number
# 2015.11.01.a  01-Nov-2015  2015.0  Unprovoked  MOZAMBIQUE  Inhambane Province
# 2009.12.22    22-Dec-2009  2009.0  Unprovoked  MOZAMBIQUE     Maputo Province
# 1998.04.26    26-Apr-1998  1998.0  Unprovoked  MOZAMBIQUE                Gaza
# 1998.01.14    14-Jan-1998  1998.0  Unprovoked  MOZAMBIQUE     Maputo Province
#
#                                         Location              Activity  \
# Case Number
# 2015.11.01.a                              Maxixe               Fishing
# 2009.12.22                         Ponta do Ouro              Swimming
# 1998.04.26    Bilene Bay, 180 km north of Maputo  Towing rubber dinghy
# 1998.01.14                         Ponta do Ouro               Surfing
#
#                               Name Sex Age  \
# Case Number
# 2015.11.01.a        Albino Ernesto   M  19
# 2009.12.22            Peter Fraser   M  27
# 1998.04.26    Wilma van Molendorff   F  35
# ...

# %%
Thailand_df = df2.loc[df2["Country"] == "THAILAND"]
Thailand_df
#15.8700° N, 100.9925° E
# Out:
#                     Date    Year        Type   Country    Area     Location  \
# Case Number
# 2015.09.01   01-Sep-2015  2015.0  Unprovoked  THAILAND  Phuket  Karon Beach
#
#             Activity        Name Sex Age                    Injury  \
# Case Number
# 2015.09.01    Wading  Jane Neame   F  37  Left foot & ankle bitten
#
#             Fatal (Y/N)   Time      Species    Investigator or Source  \
# Case Number
# 2015.09.01            N  08h30  small shark  Phuket Gazette, 9/1/2015
#
#                               pdf  \
# Case Number
# 2015.09.01   2015.09.01-Neame.pdf
#
#                                                           href
# Case Number
# 2015.09.01   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
Puerto_Rico_df = df2.loc[df2["Country"] == "PUERTO RICO"]
Puerto_Rico_df
#18.2208° N, 66.5901° W
# Out:
#                     Date    Year        Type      Country Area       Location  \
# Case Number
# 2015.06.19   19-Jun-2015  2015.0  Unprovoked  PUERTO RICO  NaN  Off Cabo Rojo
#
#                  Activity           Name Sex Age          Injury Fatal (Y/N)  \
# Case Number
# 2015.06.19   Spearfishing  Benjamin Rios   M  36  Injury to hand           N
#
#                 Time Species Investigator or Source                  pdf  \
# Case Number
# 2015.06.19   Morning     NaN  Yahoo News, 6/19/2015  2015.06.19-Rios.pdf
#
#                                                           href
# Case Number
# 2015.06.19   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
PAPUA_NEW_GUINEA_df = df2.loc[df2["Country"] == "PAPUA NEW GUINEA"]
PAPUA_NEW_GUINEA_df
#6.3150° S, 143.9555° E
# Out:
#                               Date    Year        Type           Country  \
# Case Number
# 2014.02.17    Reported 17-Feb-2014  2014.0     Boating  PAPUA NEW GUINEA
# 2011.09.11.a           11-Sep-2011  2011.0  Unprovoked  PAPUA NEW GUINEA
#
#                           Area                 Location      Activity  \
# Case Number
# 2014.02.17                 NaN                      NaN       Sailing
# 2011.09.11.a  Central Province  Hula, near Port Moresby  Kite Surfing
#
#                      Name Sex Age                               Injury  \
# Case Number
# 2014.02.17         OneDLL   M  21  No injury to occupants, hull bitten
# 2011.09.11.a  Thomas Viot   M  30             Lacerations to right leg
#
#              Fatal (Y/N)       Time          Species  \
# Case Number
# 2014.02.17             N      Night              NaN
# 2011.09.11.a           N  Afternoon  Tiger shark, 2m
#
#                         Investigator or Source                    pdf  \
# Case Number
# ...

# %%
France_df = df2.loc[df2["Country"] == "FRANCE"]
France_df
#46.2276° N, 2.2137° E
# Out:
#                     Date    Year        Type Country               Area  \
# Case Number
# 2014.05.23   23-May-2014  2014.0  Unprovoked  FRANCE  Wallis and Futuna
# 2013.08.26   26-Aug-2013  2013.0    Provoked  FRANCE      Bay of Biscay
#
#                   Location                     Activity           Name Sex  \
# Case Number
# 2014.05.23   Wallis Island                 Scuba diving  Eric Barnabas   M
# 2013.08.26             NaN  Longline fishing for sharks    Ramon Arufe   M
#
#              Age                                             Injury  \
# Case Number
# 2014.05.23   NaN                  Lacerations to left thigh and hip
# 2013.08.26    50  Laceration to right arm from hooked shark  PRO...
#
#             Fatal (Y/N)     Time         Species      Investigator or Source  \
# Case Number
# 2014.05.23            N  Morning        3m shark                Facebook.com
# 2013.08.26            N    20h30  Mako shark, 5'  Diariovasco.com, 8/28/2013
#
# ...

# %%
Israel_df = df2.loc[df2["Country"] == "ISRAEL"]
Israel_df
#31.0461° N, 34.8516° E
# Out:
#                      Date    Year        Type Country               Area  \
# Case Number
# 2013.09.29.a  29-Sep-2013  2013.0  Unprovoked  ISRAEL  Southern District
#
#              Location Activity      Name Sex Age        Injury Fatal (Y/N)  \
# Case Number
# 2013.09.29.a   Ashdod   Diving  Erez Lev   M  27  Hand bitten            N
#
#                Time Species      Investigator or Source                   pdf  \
# Case Number
# 2013.09.29.a  11h30     NaN  Times of Israel, 9/30/2013  2013.09.29.a-Lev.pdf
#
#                                                            href
# Case Number
# 2013.09.29.a  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
Palestine_df = df2.loc[df2["Country"] == "PALESTINIAN TERRITORIES"]
Palestine_df
#31.9522° N, 35.2332° E
# Out:
#                      Date    Year      Type                  Country Area  \
# Case Number
# 2013.05.23.a  23-May-2013  2013.0  Provoked  PALESTINIAN TERRITORIES  NaN
#
#              Location Activity         Name Sex Age  \
# Case Number
# 2013.05.23.a     Gaza  Fishing  Hamed Salah   M  30
#
#                                           Injury Fatal (Y/N)     Time Species  \
# Case Number
# 2013.05.23.a  Two fingers lost PROVOKED INCIDENT           N  Evening     NaN
#
#                     Investigator or Source                   pdf  \
# Case Number
# 2013.05.23.a  Ma'an News Agency, 5/25/2013  2013.05.23-Salah.pdf
#
#                                                            href
# Case Number
# 2013.05.23.a  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
Jamaica_df = df2.loc[df2["Country"] == "JAMAICA"]
Jamaica_df
#18.1096° N, 77.2975° W
# Out:
#                     Date    Year        Type  Country           Area  \
# Case Number
# 2013.03.12   12-Mar-2013  2013.0  Unprovoked  JAMAICA  St. Catherine
#
#                              Location      Activity          Name Sex Age  \
# Case Number
# 2013.03.12   Pillikin Red Light area   Spearfishing  George Facey   M  68
#
#             Injury Fatal (Y/N)   Time             Species  \
# Case Number
# 2013.03.12   FATAL           Y  09h00  Tiger shark, 4.8 m
#
#                                         Investigator or Source  \
# Case Number
# 2013.03.12   R. Turner & A. Williams, Jamaica Star, 3/13/2013
#
#                               pdf  \
# Case Number
# 2013.03.12   2013.03.12-Facey.pdf
#
#                                                           href
# Case Number
# 2013.03.12   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
Russia_df = df2.loc[df2["Country"] == "RUSSIA"]
Russia_df
#61.5240° N, 105.3188° E
# Out:
#                      Date    Year        Type Country  \
# Case Number
# 2011.08.26    26-Aug-2011  2011.0  Unprovoked  RUSSIA
# 2011.08.17.a  17-Aug-2011  2011.0  Unprovoked  RUSSIA
#
#                                                            Area   Location  \
# Case Number
# 2011.08.26                                       Primorsky Krai  Slavyanka
# 2011.08.17.a  Telyakovsky Bay, Khasan,  Primorsky Krai (Far ...     Vityaz
#
#                                     Activity            Name Sex  Age  \
# Case Number
# 2011.08.26    Standing, collecting sea stars  Pavel Nechaev    M  NaN
# 2011.08.17.a                        Swimming  Denis Udovenko   M   25
#
#                                           Injury Fatal (Y/N)     Time  \
# Case Number
# 2011.08.26    Superficial laceration to shoulder           N  Morning
# 2011.08.17.a                       Hands severed           N  Evening
#
#                 Species      Investigator or Source  \
# Case Number
# ...

# %%
SEYCHELLES_df = df2.loc[df2["Country"] == "SEYCHELLES"]
SEYCHELLES_df
#4.6796° S, 55.4920° E
# Out:
#                      Date    Year        Type     Country     Area  \
# Case Number
# 2011.08.16.a  16-Aug-2011  2011.0  Unprovoked  SEYCHELLES  Praslin
# 2011.08.01    01-Aug-2011  2011.0  Unprovoked  SEYCHELLES  Praslin
#
#                  Location                Activity                Name Sex Age  \
# Case Number
# 2011.08.16.a  Anse Lazio   Swimming or Snorkeling  Ian Martin Redmond   M  30
# 2011.08.01    Anse Lazio                   Diving    Nicolas Virolle    M  36
#
#              Injury Fatal (Y/N)   Time         Species  \
# Case Number
# 2011.08.16.a  FATAL           Y  16h30  Bull shark, 6'
# 2011.08.01    FATAL           Y  15h30             NaN
#
#                                Investigator or Source  \
# Case Number
# 2011.08.16.a   P. Cahalan, The Independent, 8/17/2011
# 2011.08.01    Gulf News, 8/2/2011; Clicanoo, 8/4/2011
#
#                                    pdf  \
# Case Number
# 2011.08.16.a  2011.08.16.a-Redmond.pdf
# ...

# %%
Turks_Caicos_df = df2.loc[df2["Country"] == "TURKS & CAICOS"]
Turks_Caicos_df
#21.6940° N, 71.7979° W
# Out:
#                     Date    Year          Type         Country  \
# Case Number
# 2011.06.30   30-Jun-2011  2011.0    Unprovoked  TURKS & CAICOS
# 2007.05.04   04-May-2007  2007.0  Sea Disaster  TURKS & CAICOS
# 2002.11.14   14-Nov-2002  2002.0    Unprovoked  TURKS & CAICOS
#
#                        Area       Location      Activity  \
# Case Number
# 2011.06.30    Middle Caicos  Mudjin Harbor    Snorkeling
# 2007.05.04   Providenciales            NaN  Sea Disaster
# 2002.11.14      Caicos Bank     French Cay    Snorkeling
#
#                                                           Name  Sex  Age  \
# Case Number
# 2011.06.30                                      Tyler Cyronak     M   28
# 2007.05.04   Haitian refugees perished when their boat caps...  NaN  NaN
# 2002.11.14                                      Michelle Glenn    F   41
#
#                                                         Injury Fatal (Y/N)  \
# Case Number
# ...

# %%
FIJI_df = df2.loc[df2["Country"] == "FIJI"]
FIJI_df
# Out:
#                      Date    Year        Type Country  \
# Case Number
# 2011.04.08    08-Apr-2011  2011.0  Unprovoked    FIJI
# 2011.03.21.a  21-Mar-2011  2011.0  Unprovoked    FIJI
# 2010.12.17    17-Dec-2010  2010.0  Unprovoked    FIJI
# 2010.02.15    15-Feb-2010  2010.0  Unprovoked    FIJI
# 2008.05.14    14-May-2008  2008.0  Unprovoked    FIJI
# 2006.03.19    18-Mar-2006  2006.0  Unprovoked    FIJI
# 2003.09.29    29-Sep-2003  2003.0  Unprovoked    FIJI
# 2002.02.11    11-Feb-2002  2002.0  Unprovoked    FIJI
# 2000.12.12    12-Dec-2000  2000.0  Unprovoked    FIJI
# 1997.06.15    15-Jun-1997  1997.0  Unprovoked    FIJI
#
#                                               Area  \
# Case Number
# 2011.04.08                               Vitu Levu
# 2011.03.21.a                                   NaN
# 2010.12.17                               Vitu Levu
# 2010.02.15                          Off Vanua Levu
# 2008.05.14                          Yasawa Islands
# ...

# %%
Tonga_df = df2.loc[df2["Country"] == "TONGA"]
Tonga_df
#21.1790° S, 175.1982° W
# Out:
#                               Date    Year          Type Country  \
# Case Number
# 2010.09.06.R  Reported 06-Sep-2010  2010.0    Unprovoked   TONGA
# 2006.02.01.b           01-Feb-2006  2006.0    Unprovoked   TONGA
# 2002.09.27.a           27-Sep-2002  2002.0      Provoked   TONGA
# 1995.08.19             19-Aug-1995  1995.0    Unprovoked   TONGA
# 1993.02.19             19-Feb-1993  1993.0  Sea Disaster   TONGA
# 1993.02.18             18-Feb-1993  1993.0  Sea Disaster   TONGA
# 1980.00.00.a                1980s   1980.0    Unprovoked   TONGA
#
#                          Area                       Location  \
# Case Number
# 2010.09.06.R          Ha'api                             NaN
# 2006.02.01.b           Vava'u                       Tuanuku
# 2002.09.27.a           Vava'u  Swimming with humpback whales
# 1995.08.19             Vavau             Near Tapana Island
# 1993.02.19    Tongapatu Group     Between 'Ata and Tongapatu
# ...

# %%
South_Korea_df = df2.loc[df2["Country"] == "SOUTH KOREA"]
South_Korea_df
#35.9078° N, 127.7669° E
# Out:
#                     Date    Year        Type      Country           Area  \
# Case Number
# 2010.08.10   10-Aug-2010  2010.0  Unprovoked  SOUTH KOREA  Jeju Province
# 1996.05.10   10-May-1996  1996.0  Unprovoked  SOUTH KOREA            NaN
# 1981.05.23   23-May-1981  1981.0  Unprovoked  SOUTH KOREA       Chungnam
#
#                     Location      Activity            Name Sex Age  \
# Case Number
# 2010.08.10       Jeju Island      Swimming   Jaylee Pierce   F  16
# 1996.05.10               NaN  Shell Diving   Lee Kwan-seok   M  33
# 1981.05.23   Wae-yeon Island  Shell diving  Pak Kyong-sun    F  27
#
#                                     Injury Fatal (Y/N)            Time  \
# Case Number
# 2010.08.10   Lacerations to left lower leg           N  Late afternoon
# 1996.05.10                           FATAL           Y           11h00
# 1981.05.23                           FATAL           Y           12h30
#
# ...

# %%
Vietnam_df = df2.loc[df2["Country"] == "VIETNAM"]
Vietnam_df
#14.0583° N, 108.2772° E
# Out:
#                      Date    Year        Type  Country                Area  \
# Case Number
# 2010.06.15    15-Jun-2010  2010.0  Unprovoked  VIETNAM  Binh Dinh Province
# 2010.05.18.c  18-May-2010  2010.0  Unprovoked  VIETNAM  Binh Dinh Province
# 2010.05.18.b  18-May-2010  2010.0  Unprovoked  VIETNAM  Binh Dinh Province
# 2010.01.09.b  09-Jan-2010  2010.0  Unprovoked  VIETNAM  Binh Dinh Province
# 2010.01.09.a  09-Jan-2010  2010.0  Unprovoked  VIETNAM  Binh Dinh Province
# 2009.07.29    29-Jul-2009  2009.0  Unprovoked  VIETNAM  Binh Dinh Province
#
#                Location  Activity                  Name Sex  Age  \
# Case Number
# 2010.06.15    Quy Nhon   Swimming       Huynh Nhu Hoang   M   17
# 2010.05.18.c  Quy Nhon   Rescuing   Nguyen Thi Thu Thao   F   58
# 2010.05.18.b  Quy Nhon   Swimming      Nguyen Thi Tanh    F   60
# 2010.01.09.b  Quy Nhon        NaN         Mang Duc Hanh   M  NaN
# 2010.01.09.a  Quy Nhon    Bathing     Nguyen Minh Tuan    M  NaN
# ...

# %%
Madagascar_df = df2.loc[df2["Country"] == "MADAGASCAR"]
Madagascar_df
#18.7669° S, 46.8691° E
# Out:
#                     Date    Year        Type     Country  \
# Case Number
# 2010.05.03   03-May-2010  2010.0  Unprovoked  MADAGASCAR
#
#                              Area                      Location      Activity  \
# Case Number
# 2010.05.03   Antsiranana Province   Ambatolaoka, Nosy Be Island  Scuba diving
#
#                       Name Sex Age                      Injury Fatal (Y/N)  \
# Case Number
# 2010.05.03   Michel Touzet   M  59  Lacerations to arm & chest           N
#
#               Time Species            Investigator or Source  \
# Case Number
# 2010.05.03   09h30     NaN  M.Touzel; Shark Attack Survivors
#
#                                pdf  \
# Case Number
# 2010.05.03   2010.05.03-Touzet.pdf
#
#                                                           href
# Case Number
# 2010.05.03   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
UAE_df = df2.loc[df2["Country"] == "UNITED ARAB EMIRATES (UAE)"]
UAE_df
#23.4241° N, 53.8478° E
# Out:
#                      Date    Year        Type                     Country  \
# Case Number
# 2010.01.22.b  22-Jan-2010  2010.0  Unprovoked  UNITED ARAB EMIRATES (UAE)
#
#                Area                 Location Activity              Name Sex  \
# Case Number
# 2010.01.22.b  Dubai  Umm Suqeim Beach, Dubai  Surfing  Michael Geraghty   M
#
#              Age                        Injury Fatal (Y/N)     Time Species  \
# Case Number
# 2010.01.22.b  54  Laceration to bottom of foot           N  Evening     NaN
#
#              Investigator or Source                        pdf  \
# Case Number
# 2010.01.22.b      C. Eksander, GSAF  2010.01.22.b-Geraghty.pdf
#
#                                                            href
# Case Number
# 2010.01.22.b  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
Panama_df = df2.loc[df2["Country"] == "PANAMA"]
Panama_df
#8.5380° N, 80.7821° W
# Out:
#                     Date    Year        Type Country        Area  \
# Case Number
# 2009.10.18   18-Oct-2009  2009.0  Unprovoked  PANAMA       Bocas
# 2008.07.27   27-Jul-2008  2008.0  Unprovoked  PANAMA  San Carlos
#
#                      Location             Activity            Name Sex  Age  \
# Case Number
# 2009.10.18   Playa La Cabaña                Wading          female   F   10
# 2008.07.27         Playa Teta  Swimming or surfing  Gerardo Solis    M  NaN
#
#                                  Injury Fatal (Y/N)   Time    Species  \
# Case Number
# 2009.10.18           Arm & torso bitten           N  18h30        NaN
# 2008.07.27   5 lacerations to left foot           N  18h00  3'  shark
#
#                               Investigator or Source                    pdf  \
# Case Number
# 2009.10.18                                 A. Blaker  2009.10.18-Panama.pdf
# 2008.07.27   International Herald Tribune, 7/28/2008   2008.07.27-Solis.pdf
#
# ...

# %%
Scotland_df = df2.loc[df2["Country"] == "SCOTLAND"]
Scotland_df
#56.4907° N, 4.2026° W
# Out:
#                     Date    Year      Type   Country  Area  \
# Case Number
# 2009.10.17   17-Oct-2009  2009.0  Provoked  SCOTLAND  Fife
#
#                             Location Activity  Name Sex Age  \
# Case Number
# 2009.10.17   Deep Sea World Aquarium   Diving  male   M  23
#
#                                                         Injury Fatal (Y/N)  \
# Case Number
# 2009.10.17   15-20 puncture wounds to arm by captive shark ...           N
#
#               Time      Species       Investigator or Source  \
# Case Number
# 2009.10.17   14h45  Angel shark  Telegraph.co.uk, 10/18/2009
#
#                                      pdf  \
# Case Number
# 2009.10.17   2009.10.17-DeepSeaWorld.pdf
#
#                                                           href
# Case Number
# 2009.10.17   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
UK_df = df2.loc[df2["Country"] == "UNITED KINGDOM"]
UK_df
#55.3781° N, 3.4360° W
# Out:
#                     Date    Year      Type         Country   Area  \
# Case Number
# 2009.10.02   02-Oct-2009  2009.0  Provoked  UNITED KINGDOM  Devon
#
#                   Location Activity  Name Sex Age  \
# Case Number
# 2009.10.02   Mewstone Rock  Fishing  male   M  39
#
#                                                         Injury Fatal (Y/N)  \
# Case Number
# 2009.10.02   Injury to forearm from shark's spine PROVOKED ...           N
#
#               Time  Species Investigator or Source                pdf  \
# Case Number
# 2009.10.02   12h50  Spurdog  The Herald, 10/2/2009  2009.10.02-UK.pdf
#
#                                                           href
# Case Number
# 2009.10.02   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
Taiwan_df = df2.loc[df2["Country"] == "TAIWAN"]
Taiwan_df
#23.6978° N, 120.9605° E
# Out:
#                     Date    Year      Type Country              Area  \
# Case Number
# 2009.05.31   31-May-2009  2009.0  Provoked  TAIWAN  Off Green Island
#
#                                                   Location Activity  \
# Case Number
# 2009.05.31   Onboard the fishing vessel Chin Sheng Fa 13    Fishing
#
#                       Name Sex Age  \
# Case Number
# 2009.05.31   Zhang Sanqian   M  46
#
#                                                         Injury Fatal (Y/N)  \
# Case Number
# 2009.05.31   Lacerations to knee & left lower leg by electr...           N
#
#               Time      Species Investigator or Source  \
# Case Number
# 2009.05.31   20h30  80 kg shark   Taiwan News, 5/21/09
#
#                                 pdf  \
# Case Number
# 2009.05.31   2009.05.31-Sangian.pdf
#
#                                                           href
# Case Number
# 2009.05.31   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
Guam_df = df2.loc[df2["Country"] == "GUAM"]
Guam_df
#13.4443° N, 144.7937° E

# %%
Philippines_df = df2.loc[df2["Country"] == "PHILIPPINES"]
Philippines_df
#12.8797° N, 121.7740° E
# Out:
#                      Date    Year          Type      Country  \
# Case Number
# 2009.04.20    20-Apr-2009  2009.0    Unprovoked  PHILIPPINES
# 2008.11.06    06-Nov-2008  2008.0    Unprovoked  PHILIPPINES
# 2007.09.30.b  30-Sep-2007  2007.0  Sea Disaster  PHILIPPINES
# 2006.11.25    25-Nov-2006  2006.0  Sea Disaster  PHILIPPINES
# 1980.04.22    22-Apr-1980  1980.0  Sea Disaster  PHILIPPINES
#
#                            Area  \
# Case Number
# 2009.04.20    Batangas province
# 2008.11.06                Luzon
# 2007.09.30.b            Palawan
# 2006.11.25    Surigao del Norte
# 1980.04.22     Romblon Province
#
#                                                        Location  \
# Case Number
# 2009.04.20                                               Mabini
# 2008.11.06                     off Paoay, Ilocos Norte Province
# 2007.09.30.b                                   Off Cagayancillo
# 2006.11.25                  Off Bilisan Point, Hinatuarn Island
# ...

# %%
Croatia_df = df2.loc[df2["Country"] == "CROATIA"]
Croatia_df
#45.1000° N, 15.2000° E
# Out:
#                     Date    Year        Type  Country                    Area  \
# Case Number
# 2008.10.06   06-Oct-2008  2008.0  Unprovoked  CROATIA   Split-Dalmatia Count,
#
#                              Location      Activity           Name Sex Age  \
# Case Number
# 2008.10.06   Smokvina Bay, Vis Island  Spearfishing  Damjan Pecek    M  43
#
#                   Injury Fatal (Y/N)   Time          Species  \
# Case Number
# 2008.10.06   Calf bitten           N  12h00  5 m white shark
#
#             Investigator or Source                   pdf  \
# Case Number
# 2008.10.06         A. De Maddalena  2008.10.06-Pecek.pdf
#
#                                                           href
# Case Number
# 2008.10.06   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
Solomon_Islands_df = df2.loc[df2["Country"] == "SOLOMON ISLANDS"]
Solomon_Islands_df
#9.6457° S, 160.1562° E
# Out:
#                     Date    Year        Type          Country           Area  \
# Case Number
# 2007.09.17   17-Sep-2007  2007.0  Unprovoked  SOLOMON ISLANDS  Marovo Lagoon
#
#                  Location      Activity          Name Sex  Age  \
# Case Number
# 2007.09.17   Kicha Island  Spearfishing  Corey Howell   M  NaN
#
#                         Injury Fatal (Y/N)  Time          Species  \
# Case Number
# 2007.09.17   Left thigh bitten           N  Dusk  Gray reef shark
#
#             Investigator or Source                   pdf  \
# Case Number
# 2007.09.17            L. Choquette  2007.09.17-Corey.pdf
#
#                                                           href
# Case Number
# 2007.09.17   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
Yemen_df = df2.loc[df2["Country"] == "YEMEN"]
Yemen_df
#15.5527° N, 48.5164° E
# Out:
#                     Date    Year        Type Country                 Area  \
# Case Number
# 2007.03.22   22-Mar-2007  2007.0  Unprovoked   YEMEN  Muhafazat Hadramawt
#
#                Location Activity  \
# Case Number
# 2007.03.22   Ras-Alkalb   Murder
#
#                                                           Name  Sex  Age  \
# Case Number
# 2007.03.22   At least 29 (and possibly another 71) Somali &...  NaN  NaN
#
#                                                         Injury Fatal (Y/N)  \
# Case Number
# 2007.03.22   FATAL,  beaten & thrown overboard by smugglers...           Y
#
#                 Time Species  \
# Case Number
# 2007.03.22   Morning     NaN
#
#                                         Investigator or Source  \
# Case Number
# 2007.03.22   United Nations High Commission for Refugees, 3...
#
#                                           pdf  \
# Case Number
# 2007.03.22   2007.03.22-EthiopianRefugees.pdf
#
# ...

# %%
Atlantic_Ocean_df = df2.loc[df2["Country"] == "ATLANTIC OCEAN"]
Atlantic_Ocean_df
#14.5994° S, 28.6731° W
# Out:
#                     Date    Year     Type         Country  \
# Case Number
# 2005.12.20   20-Dec-2005  2005.0  Boating  ATLANTIC OCEAN
#
#                                           Area Location  \
# Case Number
# 2005.12.20   600 nm west of the Canary Islands      NaN
#
#                                                    Activity  \
# Case Number
# 2005.12.20   Competing in the Woodvale Atlantic Rowing Race
#
#                                                           Name  Sex  Age  \
# Case Number
# 2005.12.20   7 m boat, occupants: Tara Remington & Iain Rudkin  NaN  NaN
#
#                                                         Injury Fatal (Y/N)  \
# Case Number
# 2005.12.20   No injury to occupants, shark rammed boat for ...           N
#
#               Time    Species                   Investigator or Source  \
# Case Number
# 2005.12.20   13h30  3 m shark  R.D. Weeks, GSAF; NZ Herald, 12/21/2005
#
#                                 pdf  \
# Case Number
# ...

# %%
St_Maartin_df = df2.loc[df2["Country"] == "ST. MAARTIN"]
St_Maartin_df
#18.0708° N, 63.0501° W
# Out:
#                     Date    Year        Type      Country         Area  \
# Case Number
# 2005.10.25   25-Oct-2005  2005.0  Unprovoked  ST. MAARTIN  Simpson Bay
#
#                    Location  Activity           Name Sex Age  \
# Case Number
# 2005.10.25   Sunterra Beach  Standing  James Bumpers   M  55
#
#                                 Injury Fatal (Y/N)   Time   Species  \
# Case Number
# 2005.10.25   Lower right leg lacerated           N  08h00  2' shark
#
#             Investigator or Source                     pdf  \
# Case Number
# 2005.10.25         M. Levine, GSAF  2005.10.25-Bumpers.pdf
#
#                                                           href
# Case Number
# 2005.10.25   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
Grand_Cayman_df = df2.loc[df2["Country"] == "GRAND CAYMAN"]
Grand_Cayman_df
#19.3222° N, 81.2409° W
# Out:
#                     Date    Year        Type       Country       Area  \
# Case Number
# 2005.10.11   11-Oct-2005  2005.0  Unprovoked  GRAND CAYMAN  East Wall
#
#                            Location      Activity            Name Sex Age  \
# Case Number
# 2005.10.11   Jack McKenney's Canyon  Scuba diving  Lea Ann Hughes   F  57
#
#                  Injury Fatal (Y/N)   Time                Species  \
# Case Number
# 2005.10.11   No injury            N  15h00  Caribbean reef sharks
#
#                           Investigator or Source                    pdf  \
# Case Number
# 2005.10.11   L.A.Hughes; G. Holt, Scubaradio.com  2005.10.11-Hughes.pdf
#
#                                                           href
# Case Number
# 2005.10.11   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
Vanuatu_df = df2.loc[df2["Country"] == "VANUATU"]
Vanuatu_df
#15.3767° S, 166.9592° E
# Out:
#                      Date    Year        Type  Country              Area  \
# Case Number
# 2005.06.22    22-Jun-2005  2005.0  Unprovoked  VANUATU  Malampa Province
# 2004.11.11.a  11-Nov-2004  2004.0  Unprovoked  VANUATU  Malampa Province
# 1987.04.01    01-Apr-1987  1987.0  Unprovoked  VANUATU  Malampa Province
#
#                                 Location    Activity                     Name  \
# Case Number
# 2005.06.22    Atchin Island off Malakula    Swimming  Alysha Margaret Webster
# 2004.11.11.a  Malakula (Malakula Island)  Snorkeling  a German tourist (male)
# 1987.04.01                    Vao Island    Swimming                     male
#
#              Sex  Age        Injury Fatal (Y/N)       Time  \
# Case Number
# 2005.06.22     F    7         FATAL           Y  Afternoon
# 2004.11.11.a   M  30s  Thigh bitten           N      09h00
# 1987.04.01     M    8         FATAL           Y      12h00
#
#                                                         Species  \
# ...

# %%
Mexico1_df = df2.loc[df2["Country"] == "MEXICO "]
Mexico1_df
#23.6345° N, 102.5528° W
# Out:
#                     Date    Year        Type  Country             Area  \
# Case Number
# 2005.06.21   20-Jun-2005  2005.0  Unprovoked  MEXICO   Baja California
#
#                    Location Activity           Name Sex  Age  \
# Case Number
# 2005.06.21   San Luis beach  Surfing  Frank Johnson   M  NaN
#
#                        Injury Fatal (Y/N)   Time Species  \
# Case Number
# 2005.06.21   Left foot bitten           N  07h00     NaN
#
#                                         Investigator or Source  \
# Case Number
# 2005.06.21   http://www.signonsandiego.com/news/mexico/2005...
#
#                                 pdf  \
# Case Number
# 2005.06.21   2005.06.21-Johnson.pdf
#
#                                                           href
# Case Number
# 2005.06.21   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
Venezuela_df = df2.loc[df2["Country"] == "VENEZUELA"]
Venezuela_df
#6.4238° N, 66.5897° W
# Out:
#                      Date    Year        Type    Country           Area  \
# Case Number
# 2005.03.25    25-Mar-2005  2005.0  Unprovoked  VENEZUELA            NaN
# 2004.01.21.b  21-Jan-2004  2004.0  Unprovoked  VENEZUELA     Anzoategui
# 2004.01.21.a  21-Jan-2004  2004.0  Unprovoked  VENEZUELA     Anzoategui
# 2003.04.11    11-Apr-2003  2003.0  Unprovoked  VENEZUELA  Nueva Esparta
#
#                                                        Location      Activity  \
# Case Number
# 2005.03.25                                        Punta Caracas       Surfing
# 2004.01.21.b  Playa Colorada Beach, Mochima National Park, o...      Swimming
# 2004.01.21.a  Santa Cruz Beach, Mochima National Park, 250 k...  Spearfishing
# 2003.04.11                           El Yaqu, Isla de Margarita       Surfing
#
#                                          Name Sex  Age  \
# Case Number
# 2005.03.25                     Jokin Leizaola   M  NaN
# 2004.01.21.b                   Stefan Moeller   M  NaN
# ...

# %%
Micronesia_df = df2.loc[df2["Country"] == "MICRONESIA"]
Micronesia_df
#7.4256° N, 150.5508° E

# %%
Okinawa_df = df2.loc[df2["Country"] == "OKINAWA"]
Okinawa_df
#26.1202° N, 127.7025° E

# %%
Marshall_Islands_df = df2.loc[df2["Country"] == "MARSHALL ISLANDS"]
Marshall_Islands_df
#7.1315° N, 171.1845° E

# %%
Egypt_Israel_df = df2.loc[df2["Country"] == "EGYPT / ISRAEL"]
Egypt_Israel_df
#26.8206° N, 30.8025° E
# Out:
#                      Date    Year        Type         Country  \
# Case Number
# 1996.07.23.a  23-Jul-1996  1996.0  Unprovoked  EGYPT / ISRAEL
#
#                                     Area  \
# Case Number
# 1996.07.23.a  South Sinai, Gulf of Aqaba
#
#                                                        Location  \
# Case Number
# 1996.07.23.a  1 km off the mouth of Marsa Bereika, north of ...
#
#                                         Activity  \
# Case Number
# 1996.07.23.a  Free diving with a pod of dolphins
#
#                                        Name Sex  Age  \
# Case Number
# 1996.07.23.a  Martin Christopher Richardson   M  NaN
#
#                                         Injury Fatal (Y/N)   Time  \
# Case Number
# 1996.07.23.a  Bitten on back, shoulder & chest           N  18h00
#
#                                                 Species  \
# Case Number
# 1996.07.23.a  said to involve an oceanic whitetip shark
#
# ...

# %%
Hong_Kong_df = df2.loc[df2["Country"] == "HONG KONG"]
Hong_Kong_df
#22.3193° N, 114.1694° E
# Out:
#                      Date    Year        Type    Country             Area  \
# Case Number
# 1995.06.02    02-Jun-1995  1995.0  Unprovoked  HONG KONG  New Territories
# 1993.06.11.b  11-Jun-1993  1993.0  Unprovoked  HONG KONG  New Territories
# 1991.06.07.a  07-Jun-1991  1991.0  Unprovoked  HONG KONG     Port Shelter
#
#                                         Location   Activity  \
# Case Number
# 1995.06.02                  Sheung Sze Wan Beach   Swimming
# 1993.06.11.b                        Silverstrand   Swimming
# 1991.06.07.a  Silverstrand Beach, near Hung Hau   Swimming
#
#                                Name Sex Age  \
# Case Number
# 1995.06.02     Herman Lo Cheuk-Yuet   M  29
# 1993.06.11.b       Kwong Kong-hing    M  61
# 1991.06.07.a  Yeung Tam-ho (female)   F  65
#
#                                                   Injury Fatal (Y/N)  \
# Case Number
# 1995.06.02    FATAL, right thigh bitten, femur exposed             Y
# ...

# %%
Chile_df = df2.loc[df2["Country"] == "CHILE"]
Chile_df
#35.6751° S, 71.5430° W
# Out:
#                      Date    Year        Type Country       Area  \
# Case Number
# 1994.03.23.b  23-Mar-1994  1994.0  Unprovoked   CHILE        NaN
# 1994.03.23.a  23-Mar-1994  1994.0  Unprovoked   CHILE        NaN
# 1981.03.04    04-Mar-1981  1981.0  Unprovoked   CHILE   Coquimbo
# 1980.01.05    05-Jan-1980  1980.0  Unprovoked   CHILE  Los Vilos
#
#                                                  Location  \
# Case Number
# 1994.03.23.b              300 miles east of Easter Island
# 1994.03.23.a              300 miles East of Easter Island
# 1981.03.04    Bahia Totoralillo, 80  km north of Coquimbo
# 1980.01.05                       Punta Negra, Pichidangui
#
#                                                        Activity  \
# Case Number
# 1994.03.23.b  Swimming alongside NOAA research vessel Discov...
# 1994.03.23.a  Swimming alongside NOAA research vessel Discov...
# 1981.03.04                             Free diving Spearfishing
# ...

# %%
Italy_df = df2.loc[df2["Country"] == "ITALY"]
Italy_df
#41.8719° N, 12.5674° E
# Out:
#                                      Date    Year        Type Country  \
# Case Number
# 1991.07.30                    30-Jul-1991  1991.0     Boating   ITALY
# 1989.06.06                    06-Jun-1989  1989.0  Unprovoked   ITALY
# 1989.02.02                    02-Feb-1989  1989.0  Unprovoked   ITALY
# 1985.07.00   Mid Jul-1985 or mid Jul-1986  1985.0  Unprovoked   ITALY
#
#                        Area  \
# Case Number
# 1991.07.30     Ligurian Sea
# 1989.06.06          Tuscany
# 1989.02.02   Tyrrhenian Sea
# 1985.07.00           Sicily
#
#                                                       Location  \
# Case Number
# 1991.07.30   Portofino, 20 miles offshore, Tigullio Bay, Sa...
# 1989.06.06   Marinella, between Punta Blanca & Marine del C...
# 1989.02.02           Golfo di Baratti, near Piombino (Tuscany)
# 1985.07.00                                         Punta Secca
#
#                                           Activity              Name Sex  Age  \
# Case Number
# ...
